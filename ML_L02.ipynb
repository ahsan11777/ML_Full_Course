# %% [markdown]
# <a href="https://colab.research.google.com/github/ahsan11777/ML_Full_Course/blob/main/ML_L02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model

# %% [markdown]
# # Area(Independent variable) & Price(Dependent variable)

# %%
path="/content/drive/MyDrive/ML-Course/L2_Liner_regresssion/Home_price_data1.csv"
df=pd.read_csv(path)
df.head(5)
# Out:
#    Area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %% [markdown]
# ### plot a scatter plot to get an idea on distribution of my data point

# %%
# %matplotlib inline
plt.xlabel('Area')
plt.ylabel('price')
plt.scatter(df.Area,df.price,color='red',marker='+')

# %%
# %matplotlib inline
plt.xlabel('Area',fontsize=20)
plt.ylabel('price',fontsize=20)
plt.scatter(df.Area,df.price,color='red',marker='+')
plt.plot(df.Area,reg.predict(df[['Area']]),color='blue')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['Area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %% [markdown]
# ### Equation of simple linear regression is: Y=mX+c

# %%
135.78767123*3300+180616.43835616432
# Out:
# 628715.7534151643

# %%
d=pd.read_csv("/content/drive/MyDrive/ML-Course/L2_Liner_regresssion/Home_price_data2.csv")
d
# Out:
#     Area
# 0   1000
# 1   1500
# 2   2300
# 3   3500
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
p=reg.predict(d)

# %% [markdown]
# ## Create a new column in data frame

# %%
d["prices"]=p
d
# Out:
#     Area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3500  6.558733e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %% [markdown]
# ## Save new data frame

# %%
d.to_csv("/content/drive/MyDrive/ML-Course/L2_Liner_regresssion/Home_price_data2.csv",index=False)

# %% [markdown]
# # Exercise:Dataset( canada_per_capita_income) and predict income of 2020

# %%
c=pd.read_csv("/content/drive/MyDrive/ML-Course/L2_Liner_regresssion/canada_per_capita_income.csv")
c.head()
# Out:
#    year       income
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583

# %%
# %matplotlib inline
plt.xlabel('year',fontsize=20)
plt.ylabel( 'income',fontsize=20)
plt.scatter(c.year,c.income,color='red',marker='+')

# %%
reg=linear_model.LinearRegression()
reg.fit(c[['year']],c.income)
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %% [markdown]
# #Predicted income of 2020 is 41288.69409442
